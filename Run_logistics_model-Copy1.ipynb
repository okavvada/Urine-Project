# %%
from __future__ import division
from sklearn.cluster import  MiniBatchKMeans, KMeans, DBSCAN
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import pandas as pd
import math
from pylab import *
from scipy.spatial.distance import cdist
from scipy import spatial
from mpl_toolkits.mplot3d import Axes3D

# %%
from Parameters import *
from logistics_functions import *
from logistics_model import *
from Parameters import time_between_catridge_regeneration, collection_times_per_year

# %%
n_regen = 30
n_collection = 1
schedule = 'scheduled'
path = '..\shapefiles\\building_block_people_WGS_2.csv'
logistics = 'grid'

# %%
Logistics = logistics_model(path, n_regen, n_collection, schedule, logistics)
distance_regeneration, distance_collection = Logistics.logistics_distances()

# %%
distance_regeneration
# Out:
#     cluster  num_people  total_dist_m
# 0         0           2      0.000000
# 1         1       19736   3506.610527
# 2         2       17393   2742.139865
# 3         3       23772   3961.855576
# 4         4        6365   1537.344786
# 5         5          59     80.441267
# 6         6       34282   4868.219186
# 7         7       21328   3459.989357
# 8         8       24768   5471.443792
# 9         9       23644   5511.783214
# 10       10        6432   1354.511392
# 11       11       33518   4623.484350
# 12       12       23473   3836.749947
# 13       13       14219   4841.490980
# 14       14       47385   9715.783881
# 15       15       40338   4983.561503
# 16       16       48354   4636.963833
# 17       17       39289   5724.786201
# 18       18       29701   5884.384719
# 19       19       55966   9465.856901
# 20       20       58245   4109.015315
# 21       21       54915   2466.413896
# 22       22       27733   3138.019328
# 23       23       30309   4794.106721
# 24       24       46135   7821.174408
# 25       25        4803   1399.105380
# 26       26       16006    907.525234
# 27       27        5923   1211.763753
# 28       28        3070    669.332703
